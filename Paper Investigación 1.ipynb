# %%
import fastf1
import fastf1.plotting
import pandas as pd 
import numpy as np
import re
from matplotlib import pyplot as plt
print(fastf1.__version__)
from fastf1 import utils
from fastf1.core import Laps
import fastf1.plotting
import matplotlib.pyplot as plt


fastf1.plotting.setup_mpl(misc_mpl_mods=False)
# Out:
# 3.0.7

# %%
fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")
session = fastf1.get_session(2024,"Bahrain","FP1")
session.load()
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '10', '11', '14', '16', '18', '2', '20', '22', '23', '24', '27', '3', '31', '4', '44', '55', '63', '77', '81']

# %%
results=session.results
results
# Out:
#    DriverNumber BroadcastName Abbreviation         DriverId         TeamName  \
# 1             1  M VERSTAPPEN          VER   max_verstappen  Red Bull Racing
# 10           10       P GASLY          GAS            gasly           Alpine
# 11           11       S PEREZ          PER            perez  Red Bull Racing
# 14           14      F ALONSO          ALO           alonso     Aston Martin
# 16           16     C LECLERC          LEC          leclerc          Ferrari
# 18           18      L STROLL          STR           stroll     Aston Martin
# 2             2    L SARGEANT          SAR         sargeant         Williams
# 20           20   K MAGNUSSEN          MAG  kevin_magnussen     Haas F1 Team
# 22           22     Y TSUNODA          TSU          tsunoda               RB
# 23           23       A ALBON          ALB            albon         Williams
# 24           24        G ZHOU          ZHO             zhou      Kick Sauber
# 27           27  N HULKENBERG          HUL       hulkenberg     Haas F1 Team
# 3             3   D RICCIARDO          RIC        ricciardo               RB
# 31           31        E OCON          OCO             ocon           Alpine
# 4             4      L NORRIS          NOR           norris          McLaren
# 44           44    L HAMILTON          HAM         hamilton         Mercedes
# 55           55       C SAINZ          SAI            sainz          Ferrari
# 63           63     G RUSSELL          RUS          russell         Mercedes
# 77           77      V BOTTAS          BOT           bottas      Kick Sauber
# 81           81     O PIASTRI          PIA          piastri          McLaren
#
#    TeamColor        TeamId  FirstName    LastName          FullName  ...  \
# 1     3671c6      red_bull        Max  Verstappen    Max Verstappen  ...
# 10    ff87bc        alpine     Pierre       Gasly      Pierre Gasly  ...
# 11    3671c6      red_bull     Sergio       Perez      Sergio Perez  ...
# 14    229971  aston_martin   Fernando      Alonso   Fernando Alonso  ...
# 16    e8002d       ferrari    Charles     Leclerc   Charles Leclerc  ...
# 18    229971  aston_martin      Lance      Stroll      Lance Stroll  ...
# 2     64c4ff      williams      Logan    Sargeant    Logan Sargeant  ...
# 20    b6babd          haas      Kevin   Magnussen   Kevin Magnussen  ...
# 22    6692ff            rb       Yuki     Tsunoda      Yuki Tsunoda  ...
# 23    64c4ff      williams  Alexander       Albon   Alexander Albon  ...
# 24    52e252        sauber     Guanyu        Zhou       Guanyu Zhou  ...
# 27    b6babd          haas       Nico  Hulkenberg   Nico Hulkenberg  ...
# 3     6692ff            rb     Daniel   Ricciardo  Daniel Ricciardo  ...
# 31    ff87bc        alpine    Esteban        Ocon      Esteban Ocon  ...
# 4     ff8000       mclaren      Lando      Norris      Lando Norris  ...
# 44    27f4d2      mercedes      Lewis    Hamilton    Lewis Hamilton  ...
# 55    e8002d       ferrari     Carlos       Sainz      Carlos Sainz  ...
# 63    27f4d2      mercedes     George     Russell    George Russell  ...
# 77    52e252        sauber   Valtteri      Bottas   Valtteri Bottas  ...
# 81    ff8000       mclaren      Oscar     Piastri     Oscar Piastri  ...
#
#    CountryCode Position  ClassifiedPosition GridPosition  Q1  Q2  Q3 Time  \
# 1          NED      NaN                              NaN NaT NaT NaT  NaT
# 10         FRA      NaN                              NaN NaT NaT NaT  NaT
# 11         MEX      NaN                              NaN NaT NaT NaT  NaT
# 14         ESP      NaN                              NaN NaT NaT NaT  NaT
# 16         MON      NaN                              NaN NaT NaT NaT  NaT
# 18         CAN      NaN                              NaN NaT NaT NaT  NaT
# 2          USA      NaN                              NaN NaT NaT NaT  NaT
# 20         DEN      NaN                              NaN NaT NaT NaT  NaT
# 22         JPN      NaN                              NaN NaT NaT NaT  NaT
# 23         THA      NaN                              NaN NaT NaT NaT  NaT
# 24         CHN      NaN                              NaN NaT NaT NaT  NaT
# 27         GER      NaN                              NaN NaT NaT NaT  NaT
# 3          AUS      NaN                              NaN NaT NaT NaT  NaT
# 31         FRA      NaN                              NaN NaT NaT NaT  NaT
# 4          GBR      NaN                              NaN NaT NaT NaT  NaT
# 44         GBR      NaN                              NaN NaT NaT NaT  NaT
# 55         ESP      NaN                              NaN NaT NaT NaT  NaT
# 63         GBR      NaN                              NaN NaT NaT NaT  NaT
# 77         FIN      NaN                              NaN NaT NaT NaT  NaT
# 81         AUS      NaN                              NaN NaT NaT NaT  NaT
#
#    Status Points
# 1            NaN
# 10           NaN
# 11           NaN
# 14           NaN
# 16           NaN
# 18           NaN
# 2            NaN
# 20           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 27           NaN
# 3            NaN
# 31           NaN
# 4            NaN
# 44           NaN
# 55           NaN
# 63           NaN
# 77           NaN
# 81           NaN
#
# [20 rows x 21 columns]

# %%
q1=pd.DataFrame(columns=["Driver","LapTime","Position","GapToKnockout","Session"])
q2=pd.DataFrame(columns=["Driver","LapTime","Position","GapToKnockout","Session"])
results=session.results


print(results["Status"])

# %%
fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")
session = fastf1.get_session(2021, 7, 'R')
session.load()
session.laps

# %%
# Assuming 'session' is already loaded and contains the results.
results = session.results[["Abbreviation", "TeamName", "Q1", "Q2"]]

# Q1 dataframe
q1 = results[["Abbreviation", "TeamName", "Q1"]].sort_values(by="Q1").reset_index(drop=True)
q1.columns = ["Driver", "Team", "LapTime"]
q1["Position"] = q1.index + 1
knockout_time_q1 = q1.iloc[14]["LapTime"]  # 15th place time
q1["GapToKnockout"] = q1["LapTime"] - knockout_time_q1
q1["Session"] = "Q1"

# Q2 dataframe
q2 = results[["Abbreviation", "TeamName", "Q2"]].dropna().sort_values(by="Q2").reset_index(drop=True)
q2.columns = ["Driver", "Team", "LapTime"]
q2["Position"] = q2.index + 1
knockout_time_q2 = q2.iloc[9]["LapTime"]  # 10th place time
q2["GapToKnockout"] = q2["LapTime"] - knockout_time_q2
q2["Session"] = "Q2"

# Display the final dataframes
print(q1)
print(q2)

# %%
import pandas as pd
from fastf1 import get_session

# Define the years and GPs to process
years = [2019, 2020, 2021, 2022, 2023]
gps = ["Bahrain", "Saudi Arabia", "Australia", "Japan", "China",
       "Miami", "Imola", "Monaco", "Spain", "Canada",
       "Austria", "Great Britain", "Hungary", "Belgium", "Netherlands",
       "Azerbaijan", "Singapore", "Austin", "Mexico", "Brazil",
       "Qatar", "Abu Dhabi", "Monza"]

# Initialize empty DataFrames for Q1 and Q2 data
q1_combined = pd.DataFrame(columns=["Driver", "Team", "LapTime", "Position", "GapToKnockout", "Session", "Year", "GP"])
q2_combined = pd.DataFrame(columns=["Driver", "Team", "LapTime", "Position", "GapToKnockout", "Session", "Year", "GP"])

# Loop through each year and GP
for year in years:
    for gp in gps:
        try:
            # Load the session data
            session = get_session(year, gp, 'Q')
            session.load()

            # Extract relevant results
            results = session.results[["Abbreviation", "TeamName", "Q1", "Q2"]]
            results["Q1"] = results["Q1"].dt.total_seconds()
            results["Q2"] = results["Q2"].dt.total_seconds()

            # Process Q1 data
            q1 = results[["Abbreviation", "TeamName", "Q1"]].sort_values(by="Q1").reset_index(drop=True)
            q1.columns = ["Driver", "Team", "LapTime"]
            q1["Position"] = q1.index + 1
            knockout_time_q1 = q1.iloc[14]["LapTime"]  # 15th place time
            q1["GapToKnockout"] = q1["LapTime"] - knockout_time_q1
            q1["Session"] = "Q1"
            q1["Year"] = year
            q1["GP"] = gp
            q1_combined = pd.concat([q1_combined, q1], ignore_index=True)

            # Process Q2 data
            q2 = results[["Abbreviation", "TeamName", "Q2"]].dropna().sort_values(by="Q2").reset_index(drop=True)
            q2.columns = ["Driver", "Team", "LapTime"]
            q2["Position"] = q2.index + 1
            knockout_time_q2 = q2.iloc[9]["LapTime"]  # 10th place time
            q2["GapToKnockout"] = q2["LapTime"] - knockout_time_q2
            q2["Session"] = "Q2"
            q2["Year"] = year
            q2["GP"] = gp
            q2_combined = pd.concat([q2_combined, q2], ignore_index=True)
        
        except Exception as e:
            print(f"Failed to process {gp} {year}: {e}")

# Save the combined data to CSV files
q1_combined.to_csv("PaperQ1Data.csv", index=False)
q2_combined.to_csv("PaperQ2Data.csv", index=False)

# %%
#qualy
import pandas as pd
from fastf1 import get_session

fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")
# Define the years and their corresponding GPs
gps_by_year = {
    2019: ["Bahrain", "China", "Australia", "Japan", "Monaco", "Spain", "Canada", 
           "Austria", "Great Britain", "Hungary", "Belgium", "Azerbaijan", 
           "Singapore", "Austin", "Mexico", "Brazil", "Abu Dhabi", "Monza",
           "France", "Germany","Russia"],

    2020: ["Bahrain", "Spain", "Austria", "Great Britain", "Hungary", "Belgium", 
           "Abu Dhabi", "Monza", "Turkey", "Portugal", "Russia", "Imola", 
           "Eifel", "Mugello", "Sakhir","70th","Sakhir"],

    2021: ["Bahrain", "Monaco", "Spain", "Imola", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Azerbaijan", "Austin", 
           "Mexico", "Brazil", "Abu Dhabi", "Monza", "Qatar", "Saudi Arabia",
           "France", "Netherlands", "Turkey", "Russia","Portugal","Styria"],

    2022: ["Bahrain", "Australia", "Japan", "Monaco", "Spain", 
           "Canada", "Austria", "Great Britain", "Hungary", 
           "Belgium", "Azerbaijan", "Singapore", "Austin", "Mexico", 
           "Brazil", "Abu Dhabi", "Monza", "Qatar", "Miami", "Saudi Arabia",
           "France", "Netherlands"],

    2023: ["Bahrain", "Saudi Arabia", "Australia", "Japan", 
           "Miami", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", 
           "Azerbaijan", "Singapore", "Austin", "Mexico", "Brazil", 
           "Qatar", "Abu Dhabi", "Monza", "Las Vegas"],

    2024: ["Bahrain", "Saudi Arabia", "Australia", "Japan", 
           "China", "Miami", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", "Monza"]
}


# Initialize empty DataFrames for Q1 and Q2 data
q1_combined = pd.DataFrame(columns=["Driver", "Team", "LapTime", "Position", "GapToKnockout", "Session", "Year", "GP"])
q2_combined = pd.DataFrame(columns=["Driver", "Team", "LapTime", "Position", "GapToKnockout", "Session", "Year", "GP"])

# Loop through each year
for year, gps in gps_by_year.items():
    # Loop through each GP for the current year
    for gp in gps:
        try:
            # Load the session data
            session = get_session(year, gp, 'Q')
            session.load()

            # Extract relevant results
            results = session.results[["Abbreviation", "TeamName", "Q1", "Q2"]]
            results["Q1"] = results["Q1"].dt.total_seconds()
            results["Q2"] = results["Q2"].dt.total_seconds()

            # Process Q1 data
            q1 = results[["Abbreviation", "TeamName", "Q1"]].sort_values(by="Q1").reset_index(drop=True)
            q1.columns = ["Driver", "Team", "LapTime"]
            q1["Position"] = q1.index + 1
            knockout_time_q1 = q1.iloc[14]["LapTime"]  # 15th place time
            q1["GapToKnockout"] = q1["LapTime"] - knockout_time_q1
            q1["Session"] = "Q1"
            q1["Year"] = year
            q1["GP"] = gp
            q1_combined = pd.concat([q1_combined, q1], ignore_index=True)

            # Process Q2 data
            q2 = results[["Abbreviation", "TeamName", "Q2"]].dropna().sort_values(by="Q2").reset_index(drop=True)
            q2.columns = ["Driver", "Team", "LapTime"]
            q2["Position"] = q2.index + 1
            knockout_time_q2 = q2.iloc[9]["LapTime"]  # 10th place time
            q2["GapToKnockout"] = q2["LapTime"] - knockout_time_q2
            q2["Session"] = "Q2"
            q2["Year"] = year
            q2["GP"] = gp
            q2_combined = pd.concat([q2_combined, q2], ignore_index=True)

        except Exception as e:
            print(f"Failed to process {gp} {year}: {e}")

# Save the combined data for all years to a single CSV file
q1_combined.to_csv("PaperQ1Data2.csv", index=False)
q2_combined.to_csv("PaperQ2Data2.csv", index=False)

# %%
import pandas as pd
from fastf1 import get_session

# Define the years and their corresponding GPs
gps_by_year = {
    2019: ["Bahrain", "China", "Australia", "Japan", "Monaco", "Spain", "Canada", 
           "Austria", "Great Britain", "Hungary", "Belgium", "Azerbaijan", 
           "Singapore", "Austin", "Mexico", "Brazil", "Abu Dhabi", "Monza",
           "France", "Germany","Russia"],

    2020: ["Bahrain", "Spain", "Austria", "Great Britain", "Hungary", "Belgium", 
           "Abu Dhabi", "Monza", "Turkey", "Portugal", "Russia", "Imola", 
           "Eifel", "Mugello", "Sakhir","70th","Sakhir"],

    2021: ["Bahrain", "Monaco", "Spain", "Imola", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Azerbaijan", "Austin", 
           "Mexico", "Brazil", "Abu Dhabi", "Monza", "Qatar", "Saudi Arabia",
           "France", "Netherlands", "Turkey", "Russia","Portugal","Styria"],

    2022: ["Bahrain", "Australia", "Japan", "Monaco", "Spain", 
           "Canada", "Austria", "Great Britain", "Hungary", 
           "Belgium", "Azerbaijan", "Singapore", "Austin", "Mexico", 
           "Brazil", "Abu Dhabi", "Monza", "Qatar", "Miami", "Saudi Arabia",
           "France", "Netherlands"],

    2023: ["Bahrain", "Saudi Arabia", "Australia", "Japan", 
           "Miami", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", 
           "Azerbaijan", "Singapore", "Austin", "Mexico", "Brazil", 
           "Qatar", "Abu Dhabi", "Monza", "Las Vegas"],

    2024: ["Bahrain", "Saudi Arabia", "Australia", "Japan", 
           "China", "Miami", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", "Monza"]
}


# Initialize empty DataFrame for combined race data
race_combined = pd.DataFrame(columns=["Driver", "Team", "GridPosition", "RacePosition", "Status", "Points", "PositionDifference", "Year", "GP"])

# Loop through each year
for year, gps in gps_by_year.items():
    # Loop through each GP for the current year
    for gp in gps:
        try:
            # Load the race session data
            session = get_session(year, gp, 'R')
            session.load()

            # Extract relevant race results
            results = session.results[["Abbreviation", "TeamName", "GridPosition", "Position", "Status", "Points"]]
            results["PositionDifference"] = results["GridPosition"] - results["Position"]

            # Prepare the data for saving
            race_data = results[["Abbreviation", "TeamName", "GridPosition", "Position", "Status", "Points", "PositionDifference"]]
            race_data.columns = ["Driver", "Team", "GridPosition", "RacePosition", "Status", "Points", "PositionDifference"]
            race_data["Year"] = year
            race_data["GP"] = gp

            # Combine the data
            race_combined = pd.concat([race_combined, race_data], ignore_index=True)

        except Exception as e:
            print(f"Failed to process {gp} {year}: {e}")

# Save the combined race data to a single CSV file
race_combined.to_csv("PaperRaceDatas.csv", index=False)

# %%
#RACE
import pandas as pd
from fastf1 import get_session
import numpy as np

# Define a subset of races for testing
gps_by_year = {
    2019: ["Bahrain", "China", "Australia", "Japan", "Monaco", "Spain", "Canada", 
           "Austria", "Great Britain", "Hungary", "Belgium", "Azerbaijan", 
           "Singapore", "Austin", "Mexico", "Brazil", "Abu Dhabi", "Monza",
           "France", "Germany","Russia"],

    2020: ["Bahrain", "Spain", "Austria", "Great Britain", "Hungary", "Belgium", 
           "Abu Dhabi", "Monza", "Turkey", "Portugal", "Russia", "Imola", 
           "Eifel", "Mugello", "Sakhir","70th","Sakhir"],

    2021: ["Bahrain", "Monaco", "Spain", "Imola", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Azerbaijan", "Austin", 
           "Mexico", "Brazil", "Abu Dhabi", "Monza", "Qatar", "Saudi Arabia",
           "France", "Netherlands", "Turkey", "Russia","Portugal","Styria"],

    2022: ["Bahrain", "Australia", "Japan", "Monaco", "Spain", 
           "Canada", "Austria", "Great Britain", "Hungary", 
           "Belgium", "Azerbaijan", "Singapore", "Austin", "Mexico", 
           "Brazil", "Abu Dhabi", "Monza", "Qatar", "Miami", "Saudi Arabia",
           "France", "Netherlands"],

    2023: ["Bahrain", "Saudi Arabia", "Australia", "Japan", 
           "Miami", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", 
           "Azerbaijan", "Singapore", "Austin", "Mexico", "Brazil", 
           "Qatar", "Abu Dhabi", "Monza", "Las Vegas"],

    2024: ["Bahrain", "Saudi Arabia", "Australia", "Japan", 
           "China", "Miami", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", "Monza"]
}




# Initialize empty DataFrame for combined race data
race_combined = pd.DataFrame(columns=["Driver", "Team", "GridPosition", "RacePosition", "Status", 
                                      "Points", "PositionDifference", "Year", "GP", "ChampionshipPoints", 
                                      "LastRacePosition", "TeamChampionshipPoints", "TeammateLastRacePosition"])

# Loop through each year
for year, gps in gps_by_year.items():
    # Initialize dictionaries to keep track of championship standings
    driver_points = {}
    team_points = {}
    last_race_positions = {}

    # Loop through each GP for the current year
    for gp in gps:
        try:
            # Load the race session data
            session = get_session(year, gp, 'R')
            session.load()

            # Extract relevant race results
            results = session.results[["Abbreviation", "TeamName", "GridPosition", "Position", "Status", "Points"]]
            results["PositionDifference"] = results["GridPosition"] - results["Position"]

            # Update driver and team points
            for _, row in results.iterrows():
                driver = row["Abbreviation"]
                team = row["TeamName"]
                points = row["Points"]
                
                if driver not in driver_points:
                    driver_points[driver] = 0
                if team not in team_points:
                    team_points[team] = 0

                driver_points[driver] += points
                team_points[team] += points

                # Last race position for the driver
                last_race_positions[driver] = row["Position"]

            # Prepare the data for saving
            race_data = []
            for _, row in results.iterrows():
                driver = row["Abbreviation"]
                team = row["TeamName"]
                
                # Get points and positions
                championship_points = driver_points[driver]
                last_race_position = last_race_positions.get(driver, np.nan)
                team_championship_points = team_points.get(team, np.nan)
                
                # Find teammate's last race position
                teammates = results[results["TeamName"] == team]["Abbreviation"].tolist()
                teammates.remove(driver)
                teammate_last_race_position = last_race_positions.get(teammates[0], np.nan) if teammates else np.nan

                race_data.append({
                    "Driver": driver,
                    "Team": team,
                    "GridPosition": row["GridPosition"],
                    "RacePosition": row["Position"],
                    "Status": row["Status"],
                    "Points": row["Points"],
                    "PositionDifference": row["PositionDifference"],
                    "Year": year,
                    "GP": gp,
                    "ChampionshipPoints": championship_points,
                    "LastRacePosition": last_race_position,
                    "TeamChampionshipPoints": team_championship_points,
                    "TeammateLastRacePosition": teammate_last_race_position
                })

            # Combine the data
            race_combined = pd.concat([race_combined, pd.DataFrame(race_data)], ignore_index=True)

        except Exception as e:
            print(f"Failed to process {gp} {year}: {e}")

# Save the combined race data to a single CSV file for verification
race_combined.to_csv("PaperRaceData2.csv", index=False)

# Print the first few rows to verify the output
print(race_combined.head())

# %%
#FP1
import pandas as pd
from fastf1 import get_session

fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")

# Define the years and their corresponding GPs
gps_by_year = {
    2019: ["Bahrain", "China", "Australia", "Japan", "Monaco", "Spain", "Canada", 
           "Austria", "Great Britain", "Hungary", "Belgium", "Azerbaijan", 
           "Singapore", "Austin", "Mexico", "Brazil", "Abu Dhabi", "Monza",
           "France", "Germany","Russia"],

    2020: ["Bahrain", "Spain", "Austria", "Great Britain", "Hungary", "Belgium", 
           "Abu Dhabi", "Monza", "Turkey", "Portugal", "Russia", "Imola", 
           "Eifel", "Mugello", "Sakhir","70th","Sakhir"],

    2021: ["Bahrain", "Monaco", "Spain", "Imola", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Azerbaijan", "Austin", 
           "Mexico", "Brazil", "Abu Dhabi", "Monza", "Qatar", "Saudi Arabia",
           "France", "Netherlands", "Turkey", "Russia","Portugal","Styria"],

    2022: ["Bahrain", "Australia", "Japan", "Monaco", "Spain", 
           "Canada", "Austria", "Great Britain", "Hungary", 
           "Belgium", "Azerbaijan", "Singapore", "Austin", "Mexico", 
           "Brazil", "Abu Dhabi", "Monza", "Qatar", "Miami", "Saudi Arabia",
           "France", "Netherlands"],

    2023: ["Bahrain", "Saudi Arabia", "Australia", "Japan", 
           "Miami", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", 
           "Azerbaijan", "Singapore", "Austin", "Mexico", "Brazil", 
           "Qatar", "Abu Dhabi", "Monza", "Las Vegas"],

    2024: ["Bahrain", "Saudi Arabia", "Australia", "Japan", 
           "China", "Miami", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", "Monza"]
}


# Initialize an empty DataFrame for FP1 lap data
fp1_combined = pd.DataFrame(columns=["Driver", "Team", "LapTime", "GapToFastestFP1", "Position", "Year", "GP", "Session"])

# Loop through each year
for year, gps in gps_by_year.items():
    # Loop through each GP for the current year
    for gp in gps:
        try:
            # Load the FP1 session data
            session = get_session(year, gp, 'FP1')
            session.load()

            # Get all laps in the session
            laps = session.laps

            # Convert LapTime to total seconds
            laps['LapTime'] = laps['LapTime'].dt.total_seconds()

            # Drop rows with NaN LapTimes (e.g., if a driver did not set a valid lap time)
            laps = laps.dropna(subset=['LapTime'])

            # Get the fastest lap per driver
            fastest_laps = laps.groupby('Driver').apply(lambda x: x.nsmallest(1, 'LapTime')).reset_index(drop=True)

            # Find the fastest lap time in the session
            session_fastest_time = fastest_laps["LapTime"].min()

            # Calculate the gap to the session's fastest lap for each driver's fastest lap
            fastest_laps["GapToFastestFP1"] = fastest_laps["LapTime"] - session_fastest_time

            # Extract the necessary columns and rename them
            laps_data = fastest_laps[["Driver", "Team", "LapTime", "GapToFastestFP1"]]
            laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
            laps_data["Year"] = year
            laps_data["GP"] = gp
            laps_data["Session"] = "FP1"

            # Combine the data
            fp1_combined = pd.concat([fp1_combined, laps_data], ignore_index=True)

        except Exception as e:
            print(f"Failed to process {gp} {year}: {e}")

# Save the combined data for all years to a single CSV file
fp1_combined.to_csv("PaperFP1Data2.csv", index=False)
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/2/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"
# core           INFO 	Loading data for Chinese Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/3/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"
# core           INFO 	Loading data for Australian Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/1/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"
# core           INFO 	Loading data for Japanese Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/17/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 10
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate.
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 21 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '38', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"
# core           INFO 	Loading data for Monaco Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/6/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Driver 33: Lap timing integrity check failed for 1 lap(s)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"
# core           INFO 	Loading data for Spanish Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/5/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"
# core           INFO 	Loading data for Canadian Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/7/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 88
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate.
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 21 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '40', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"
# core           INFO 	Loading data for Austrian Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/9/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"
# core           INFO 	Loading data for British Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/10/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"
# core           INFO 	Loading data for Hungarian Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/12/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"
# core           INFO 	Loading data for Belgian Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/13/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 63
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate.
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 21 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '40', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"
# core           INFO 	Loading data for Azerbaijan Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/4/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 44
# core        WARNING 	No lap data for driver 77
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate.
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate.
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"
# core           INFO 	Loading data for Singapore Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/15/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"
# core           INFO 	Loading data for United States Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/19/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 63
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate.
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 21 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '40', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"
# core           INFO 	Loading data for Mexican Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/18/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 88
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate.
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# core        WARNING 	Car telemetry data is unavailable!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# core        WARNING 	Car position data is unavailable!
# core        WARNING 	Failed to determine `Session.t0_date`!
# ...
# core           INFO 	Finished loading data for 21 drivers: ['1', '10', '11', '14', '16', '18', '2', '20', '22', '23', '24', '27', '3', '31', '4', '44', '50', '55', '63', '77', '81']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"
# core           INFO 	Loading data for Belgian Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# Request for URL https://ergast.com/api/f1/2024/14/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '10', '11', '14', '16', '18', '2', '20', '22', '23', '24', '27', '3', '31', '4', '44', '55', '63', '77', '81']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"
# core           INFO 	Loading data for Dutch Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# Request for URL https://ergast.com/api/f1/2024/15/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 77
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate.
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# _api        WARNING 	Driver 40: Car data is incomplete!
# _api        WARNING 	Driver 77: Car data is incomplete!
# _api        WARNING 	Driver  3: Car data is incomplete!
# _api        WARNING 	Driver 97: Car data is incomplete!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# _api        WARNING 	Driver 40: Position data is incomplete!
# _api        WARNING 	Driver 77: Position data is incomplete!
# _api        WARNING 	Driver  3: Position data is incomplete!
# _api        WARNING 	Driver 97: Position data is incomplete!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 21 drivers: ['1', '10', '11', '14', '16', '18', '2', '20', '22', '23', '24', '27', '3', '31', '4', '44', '55', '63', '77', '81', '97']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"
# core           INFO 	Loading data for Italian Grand Prix - Practice 1 [v3.0.7]
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# Request for URL https://ergast.com/api/f1/2024/16/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 63
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate.
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 21 drivers: ['1', '10', '11', '12', '14', '16', '18', '20', '22', '23', '24', '27', '3', '31', '4', '43', '44', '55', '63', '77', '81']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/1783616406.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP1"

# %%
import pandas as pd
from fastf1 import get_session

fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")

# Define the years and their corresponding GPs
gps_by_year = {
    2019: ["Bahrain", "China", "Australia", "Japan", "Monaco", "Spain", "Canada", 
           "Austria", "Great Britain", "Hungary", "Belgium", "Azerbaijan", 
           "Singapore", "Austin", "Mexico", "Brazil", "Abu Dhabi", "Monza",
           "France", "Germany","Russia"],

    2020: ["Bahrain", "Spain", "Austria", "Great Britain", "Hungary", "Belgium", 
           "Abu Dhabi", "Monza", "Turkey", "Portugal", "Russia", "Imola", 
           "Eifel", "Mugello", "Sakhir","70th","Sakhir"],

    2021: ["Bahrain", "Monaco", "Spain", "Imola", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Azerbaijan", "Austin", 
           "Mexico", "Brazil", "Abu Dhabi", "Monza", "Qatar", "Saudi Arabia",
           "France", "Netherlands", "Turkey", "Russia","Portugal","Styria"],

    2022: ["Bahrain", "Australia", "Japan", "Monaco", "Spain", 
           "Canada", "Austria", "Great Britain", "Hungary", 
           "Belgium", "Azerbaijan", "Singapore", "Austin", "Mexico", 
           "Brazil", "Abu Dhabi", "Monza", "Qatar", "Miami", "Saudi Arabia",
           "France", "Netherlands"],

    2023: ["Bahrain", "Saudi Arabia", "Australia", "Japan", 
           "Miami", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", 
           "Azerbaijan", "Singapore", "Austin", "Mexico", "Brazil", 
           "Qatar", "Abu Dhabi", "Monza", "Las Vegas"],

    2024: ["Bahrain", "Saudi Arabia", "Australia", "Japan", 
           "China", "Miami", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", "Monza"]
}


# Initialize an empty DataFrame for FP1 lap data
fp1_combined = pd.DataFrame(columns=["Driver", "Team", "LapTime", "GapToFastestFP2", "Position", "Year", "GP", "Session"])

# Loop through each year
for year, gps in gps_by_year.items():
    # Loop through each GP for the current year
    for gp in gps:
        try:
            # Load the FP1 session data
            session = get_session(year, gp, 'FP2')
            session.load()

            # Get all laps in the session
            laps = session.laps

            # Convert LapTime to total seconds
            laps['LapTime'] = laps['LapTime'].dt.total_seconds()

            # Drop rows with NaN LapTimes (e.g., if a driver did not set a valid lap time)
            laps = laps.dropna(subset=['LapTime'])

            # Get the fastest lap per driver
            fastest_laps = laps.groupby('Driver').apply(lambda x: x.nsmallest(1, 'LapTime')).reset_index(drop=True)

            # Find the fastest lap time in the session
            session_fastest_time = fastest_laps["LapTime"].min()

            # Calculate the gap to the session's fastest lap for each driver's fastest lap
            fastest_laps["GapToFastestFP2"] = fastest_laps["LapTime"] - session_fastest_time

            # Extract the necessary columns and rename them
            laps_data = fastest_laps[["Driver", "Team", "LapTime", "GapToFastestFP2"]]
            laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
            laps_data["Year"] = year
            laps_data["GP"] = gp
            laps_data["Session"] = "FP2"

            # Combine the data
            fp1_combined = pd.concat([fp1_combined, laps_data], ignore_index=True)

        except Exception as e:
            print(f"Failed to process {gp} {year}: {e}")

# Save the combined data for all years to a single CSV file
fp1_combined.to_csv("PaperFP2Data2.csv", index=False)
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Chinese Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Australian Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Japanese Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Monaco Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Spanish Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Canadian Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Austrian Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for British Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Hungarian Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Belgian Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Azerbaijan Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 63
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate.
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Singapore Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for United States Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Mexican Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Brazilian Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Italian Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for French Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver 99: Ignoring late data for a previously processed lap.The data may contain errors (previous: 22; current 23)
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# Failed to process Great Britain 2024: Session type 'FP2' does not exist for this event
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# _api        WARNING 	Driver  5: Position data is incomplete!
# _api        WARNING 	Driver  6: Position data is incomplete!
# _api        WARNING 	Driver  7: Position data is incomplete!
# _api        WARNING 	Driver  8: Position data is incomplete!
# _api        WARNING 	Driver  9: Position data is incomplete!
# _api        WARNING 	Driver 12: Position data is incomplete!
# _api        WARNING 	Driver 15: Position data is incomplete!
# _api        WARNING 	Driver 17: Position data is incomplete!
# _api        WARNING 	Driver 19: Position data is incomplete!
# _api        WARNING 	Driver 21: Position data is incomplete!
# _api        WARNING 	Driver 25: Position data is incomplete!
# _api        WARNING 	Driver 26: Position data is incomplete!
# _api        WARNING 	Driver 28: Position data is incomplete!
# _api        WARNING 	Driver 29: Position data is incomplete!
# _api        WARNING 	Driver 30: Position data is incomplete!
# _api        WARNING 	Driver 31: Position data is incomplete!
# _api        WARNING 	Driver 44: Position data is incomplete!
# _api        WARNING 	Driver 55: Position data is incomplete!
# _api        WARNING 	Driver 63: Position data is incomplete!
# _api        WARNING 	Driver 77: Position data is incomplete!
# _api        WARNING 	Driver 81: Position data is incomplete!
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '10', '11', '14', '16', '18', '2', '20', '22', '23', '24', '27', '3', '31', '4', '44', '55', '63', '77', '81']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Belgian Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '10', '11', '14', '16', '18', '2', '20', '22', '23', '24', '27', '3', '31', '4', '44', '55', '63', '77', '81']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Dutch Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '10', '11', '14', '16', '18', '2', '20', '22', '23', '24', '27', '3', '31', '4', '44', '55', '63', '77', '81']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"
# core           INFO 	Loading data for Italian Grand Prix - Practice 2 [v3.0.7]
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '10', '11', '14', '16', '18', '20', '22', '23', '24', '27', '3', '31', '4', '43', '44', '55', '63', '77', '81']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/629878257.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP2"

# %%
#FP3
import pandas as pd
from fastf1 import get_session

fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")

# Define the years and their corresponding GPs
gps_by_year = {
    2019: ["Bahrain", "China", "Australia", "Japan", "Monaco", "Spain", "Canada", 
           "Austria", "Great Britain", "Hungary", "Belgium", "Azerbaijan", 
           "Singapore", "Austin", "Mexico", "Brazil", "Abu Dhabi", "Monza",
           "France", "Germany","Russia"],

    2020: ["Bahrain", "Spain", "Austria", "Great Britain", "Hungary", "Belgium", 
           "Abu Dhabi", "Monza", "Turkey", "Portugal", "Russia", "Imola", 
           "Eifel", "Mugello", "Sakhir","70th","Sakhir"],

    2021: ["Bahrain", "Monaco", "Spain", "Imola", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Azerbaijan", "Austin", 
           "Mexico", "Brazil", "Abu Dhabi", "Monza", "Qatar", "Saudi Arabia",
           "France", "Netherlands", "Turkey", "Russia","Portugal","Styria"],

    2022: ["Bahrain", "Australia", "Japan", "Monaco", "Spain", 
           "Canada", "Austria", "Great Britain", "Hungary", 
           "Belgium", "Azerbaijan", "Singapore", "Austin", "Mexico", 
           "Brazil", "Abu Dhabi", "Monza", "Qatar", "Miami", "Saudi Arabia",
           "France", "Netherlands"],

    2023: ["Bahrain", "Saudi Arabia", "Australia", "Japan", 
           "Miami", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", 
           "Azerbaijan", "Singapore", "Austin", "Mexico", "Brazil", 
           "Qatar", "Abu Dhabi", "Monza", "Las Vegas"],

    2024: ["Bahrain", "Saudi Arabia", "Australia", "Japan", 
           "China", "Miami", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", "Monza"]
}



# Initialize an empty DataFrame for FP1 lap data
fp1_combined = pd.DataFrame(columns=["Driver", "Team", "LapTime", "GapToFastestFP3", "Position", "Year", "GP", "Session"])

# Loop through each year
for year, gps in gps_by_year.items():
    # Loop through each GP for the current year
    for gp in gps:
        try:
            # Load the FP1 session data
            session = get_session(year, gp, 'FP3')
            session.load()

            # Get all laps in the session
            laps = session.laps

            # Convert LapTime to total seconds
            laps['LapTime'] = laps['LapTime'].dt.total_seconds()

            # Drop rows with NaN LapTimes (e.g., if a driver did not set a valid lap time)
            laps = laps.dropna(subset=['LapTime'])

            # Get the fastest lap per driver
            fastest_laps = laps.groupby('Driver').apply(lambda x: x.nsmallest(1, 'LapTime')).reset_index(drop=True)

            # Find the fastest lap time in the session
            session_fastest_time = fastest_laps["LapTime"].min()

            # Calculate the gap to the session's fastest lap for each driver's fastest lap
            fastest_laps["GapToFastestFP3"] = fastest_laps["LapTime"] - session_fastest_time

            # Extract the necessary columns and rename them
            laps_data = fastest_laps[["Driver", "Team", "LapTime", "GapToFastestFP3"]]
            laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
            laps_data["Year"] = year
            laps_data["GP"] = gp
            laps_data["Session"] = "FP3"

            # Combine the data
            fp1_combined = pd.concat([fp1_combined, laps_data], ignore_index=True)

        except Exception as e:
            print(f"Failed to process {gp} {year}: {e}")

# Save the combined data for all years to a single CSV file
fp1_combined.to_csv("PaperFP3Data2.csv", index=False)
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for Chinese Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for Australian Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for Japanese Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# core        WARNING 	Failed to load extended driver information!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# logger      WARNING 	Failed to load session status data!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# logger      WARNING 	Failed to load track status data!
# req            INFO 	No cached data found for timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# logger      WARNING 	Failed to load timing data!
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# core        WARNING 	Car telemetry data is unavailable!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# core        WARNING 	Car position data is unavailable!
# core        WARNING 	Failed to determine `Session.t0_date`!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# logger      WARNING 	Failed to load weather data!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# logger      WARNING 	Failed to load race control messages!
# core           INFO 	Finished loading data for 20 drivers: ['77', '5', '44', '23', '55', '16', '10', '11', '18', '26', '4', '7', '8', '99', '20', '63', '88', '33', '3', '27']
# core           INFO 	Loading data for Monaco Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Failed to process Japan 2019: The data you are trying to access has not been loaded yet. See `Session.load`
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for Spanish Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for Canadian Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for Austrian Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for British Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for Hungarian Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for Belgian Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for Azerbaijan Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for Singapore Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for United States Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for Mexican Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 3
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate.
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for Brazilian Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for Italian Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for French Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['10', '11', '16', '18', '20', '23', '26', '27', '3', '33', '4', '44', '5', '55', '63', '7', '77', '8', '88', '99']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for German Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# ...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '10', '11', '14', '16', '18', '2', '20', '22', '23', '24', '27', '3', '31', '4', '44', '55', '63', '77', '81']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for Belgian Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# Request for URL https://ergast.com/api/f1/2024/14/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# _api        WARNING 	Driver 20: Ignoring late data for a previously processed lap.The data may contain errors (previous: 2; current 3)
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '10', '11', '14', '16', '18', '2', '20', '22', '23', '24', '27', '3', '31', '4', '44', '55', '63', '77', '81']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for Dutch Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# Request for URL https://ergast.com/api/f1/2024/15/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '10', '11', '14', '16', '18', '2', '20', '22', '23', '24', '27', '3', '31', '4', '44', '55', '63', '77', '81']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"
# core           INFO 	Loading data for Italian Grand Prix - Practice 3 [v3.0.7]
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# Request for URL https://ergast.com/api/f1/2024/16/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	No cached data found for session_status_data. Loading data...
# _api           INFO 	Fetching session status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for track_status_data. Loading data...
# _api           INFO 	Fetching track status data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_data. Loading data...
# _api           INFO 	Fetching timing data...
# _api           INFO 	Parsing timing data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for timing_app_data. Loading data...
# _api           INFO 	Fetching timing app data...
# req            INFO 	Data has been written to cache!
# core           INFO 	Processing timing data...
# req            INFO 	No cached data found for car_data. Loading data...
# _api           INFO 	Fetching car data...
# _api           INFO 	Parsing car data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for position_data. Loading data...
# _api           INFO 	Fetching position data...
# _api           INFO 	Parsing position data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for weather_data. Loading data...
# _api           INFO 	Fetching weather data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for race_control_messages. Loading data...
# _api           INFO 	Fetching race control messages...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['1', '10', '11', '14', '16', '18', '20', '22', '23', '24', '27', '3', '31', '4', '43', '44', '55', '63', '77', '81']
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Position"] = laps_data["LapTime"].rank().astype(int)  # Rank laps by time
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Year"] = year
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["GP"] = gp
# /var/folders/z3/f6b2q8h90wsgpsmjqkk2lnt80000gn/T/ipykernel_7519/2835120856.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   laps_data["Session"] = "FP3"

# %%
import pandas as pd
from fastf1 import get_session

fastf1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")

# Define a subset of races for testing
gps_by_year = {
    2019: ["Bahrain", "China", "Australia", "Japan", "Monaco", "Spain", "Canada", 
           "Austria", "Great Britain", "Hungary", "Belgium", "Azerbaijan", 
           "Singapore", "Austin", "Mexico", "Brazil", "Abu Dhabi", "Monza",
           "France", "Germany", "Russia"],

    2020: ["Bahrain", "Spain", "Austria", "Great Britain", "Hungary", "Belgium", 
           "Abu Dhabi", "Monza", "Turkey", "Portugal", "Russia", "Imola", 
           "Eifel", "Mugello", "Sakhir", "70th", "Sakhir"],

    2021: ["Bahrain", "Monaco", "Spain", "Imola", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Azerbaijan", "Austin", 
           "Mexico", "Brazil", "Abu Dhabi", "Monza", "Qatar", "Saudi Arabia",
           "France", "Netherlands", "Turkey", "Russia", "Portugal", "Styria"],

    2022: ["Bahrain", "Australia", "Japan", "Monaco", "Spain", 
           "Canada", "Austria", "Great Britain", "Hungary", 
           "Belgium", "Azerbaijan", "Singapore", "Austin", "Mexico", 
           "Brazil", "Abu Dhabi", "Monza", "Qatar", "Miami", "Saudi Arabia",
           "France", "Netherlands"],

    2023: ["Bahrain", "Saudi Arabia", "Australia", "Japan", 
           "Miami", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", 
           "Azerbaijan", "Singapore", "Austin", "Mexico", "Brazil", 
           "Qatar", "Abu Dhabi", "Monza", "Las Vegas"],

    2024: ["Bahrain", "Saudi Arabia", "Australia", "Japan", 
           "China", "Miami", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", "Monza"]
}

# Initialize empty DataFrame for combined pit stop data
pit_stop_data = pd.DataFrame(columns=["Driver", "Team", "Year", "GP", "StartingTire", 
                                      "NumberOfPitStops", "TiresUsed"])

# Loop through each year
for year, gps in gps_by_year.items():
    # Loop through each GP for the current year
    for gp in gps:
        try:
            # Load the race session data
            session = get_session(year, gp, 'R')
            session.load()

            # Extract lap data
            laps = session.laps

            # Initialize variables for each driver
            driver_starting_tire = {}
            driver_pit_stops = {}
            driver_tires_used = {}

            # Convert PitInTime to seconds
            laps['PitOutTime'] = laps['PitOutTime'].dt.total_seconds()

            # Filter laps to identify pit stops
            pit_stops = laps[laps['PitOutTime'] > 0]

            # Ensure we are not counting the first lap out of the pits
            valid_pit_stops = pit_stops[pit_stops['LapNumber'] > 1]

            # Loop through each lap to determine tire changes and pit stops
            for _, lap in laps.iterrows():
                driver = lap['Driver']
                compound = lap['Compound']
                
                if driver not in driver_starting_tire:
                    driver_starting_tire[driver] = compound
                
                if driver not in driver_pit_stops:
                    driver_pit_stops[driver] = 0
                
                if driver not in driver_tires_used:
                    driver_tires_used[driver] = []

                # Append the tire compound to the list for this driver
                if not driver_tires_used[driver] or driver_tires_used[driver][-1] != compound:
                    driver_tires_used[driver].append(compound)

            # Count the number of pit stops
            for _, pit in valid_pit_stops.iterrows():
                driver = pit['Driver']
                driver_pit_stops[driver] += 1

            # Prepare the data for saving
            race_data = []
            for driver in driver_starting_tire.keys():
                race_data.append({
                    "Driver": driver,
                    "Team": session.results.loc[session.results["Abbreviation"] == driver, "TeamName"].values[0],
                    "Year": year,
                    "GP": gp,
                    "StartingTire": driver_starting_tire[driver],
                    "NumberOfPitStops": driver_pit_stops.get(driver, 0),
                    "TiresUsed": ', '.join(driver_tires_used.get(driver, []))
                })

            # Combine the data
            pit_stop_data = pd.concat([pit_stop_data, pd.DataFrame(race_data)], ignore_index=True)

        except Exception as e:
            print(f"Failed to process {gp} {year}: {e}")

# Save the pit stop data to a CSV file for verification
pit_stop_data.to_csv("PitStopData.csv", index=False)

# Print the first few rows to verify the output
print(pit_stop_data.head())
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/2/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '16', '33', '5', '4', '7', '10', '23', '11', '99', '26', '20', '18', '63', '88', '27', '3', '55', '8']
# core           INFO 	Loading data for Chinese Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/3/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '5', '33', '16', '10', '3', '11', '7', '23', '8', '18', '20', '55', '99', '63', '88', '4', '26', '27']
# core           INFO 	Loading data for Australian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/1/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '5', '16', '20', '27', '7', '18', '26', '10', '4', '11', '23', '99', '63', '88', '8', '3', '55']
# core           INFO 	Loading data for Japanese Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/17/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '5', '44', '23', '55', '16', '10', '11', '18', '26', '4', '7', '8', '99', '20', '63', '88', '33', '3', '27']
# core           INFO 	Loading data for Monaco Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/6/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '5', '77', '33', '10', '55', '26', '23', '3', '8', '4', '11', '27', '20', '63', '18', '7', '88', '99', '16']
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/5/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '5', '16', '10', '20', '55', '26', '8', '23', '3', '27', '7', '11', '99', '63', '88', '18', '4']
# core           INFO 	Loading data for Canadian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/7/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '5', '16', '77', '33', '3', '27', '10', '18', '26', '55', '11', '99', '8', '7', '63', '20', '88', '23', '4']
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/9/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '16', '77', '5', '44', '4', '10', '55', '7', '99', '11', '3', '27', '18', '23', '8', '26', '63', '20', '88']
# core           INFO 	Loading data for British Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/10/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '16', '10', '33', '55', '3', '7', '26', '27', '4', '23', '18', '63', '88', '5', '11', '99', '8', '20']
# core           INFO 	Loading data for Hungarian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/12/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '5', '16', '55', '10', '7', '77', '4', '23', '11', '27', '20', '3', '26', '63', '18', '99', '88', '8']
# core           INFO 	Loading data for Belgian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/13/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '44', '77', '5', '23', '11', '26', '27', '10', '18', '4', '20', '8', '3', '63', '7', '88', '99', '55', '33']
# core           INFO 	Loading data for Azerbaijan Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/4/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '5', '33', '16', '11', '55', '4', '18', '7', '23', '99', '20', '27', '63', '88', '10', '8', '26', '3']
# core           INFO 	Loading data for Singapore Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/15/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['5', '16', '33', '44', '77', '23', '4', '10', '27', '99', '8', '55', '18', '3', '26', '88', '20', '7', '11', '63']
# core           INFO 	Loading data for United States Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/19/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '16', '23', '3', '4', '55', '27', '11', '7', '26', '18', '99', '8', '10', '63', '20', '88', '5']
# core           INFO 	Loading data for Mexican Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/18/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '5', '77', '16', '23', '33', '11', '3', '10', '27', '26', '18', '55', '99', '20', '63', '8', '88', '7', '4']
# core           INFO 	Loading data for Brazilian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/20/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '10', '55', '7', '99', '3', '44', '4', '11', '26', '20', '63', '8', '23', '27', '88', '5', '16', '18', '77']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/21/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '16', '77', '5', '23', '11', '4', '26', '55', '3', '27', '7', '20', '8', '99', '63', '10', '88', '18']
# core           INFO 	Loading data for Italian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/14/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '77', '44', '3', '27', '23', '11', '33', '99', '4', '10', '18', '5', '63', '7', '8', '88', '20', '26', '55']
# core           INFO 	Loading data for French Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/8/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '16', '33', '5', '55', '7', '27', '4', '10', '3', '11', '18', '26', '23', '99', '20', '88', '63', '8']
# core           INFO 	Loading data for German Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/11/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '5', '26', '18', '55', '23', '8', '20', '44', '88', '63', '7', '99', '10', '77', '27', '16', '4', '3', '11']
# core           INFO 	Loading data for Russian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2019/16/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '16', '33', '23', '55', '11', '4', '20', '27', '18', '26', '7', '10', '99', '88', '63', '5', '3', '8']
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/15/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '23', '4', '55', '10', '3', '77', '31', '16', '26', '63', '5', '6', '7', '99', '20', '11', '18', '8']
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/6/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '18', '11', '55', '5', '23', '10', '4', '3', '26', '31', '7', '20', '99', '63', '6', '8', '16']
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/1/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Driver  8: Lap timing integrity check failed for 1 lap(s)
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '16', '4', '44', '55', '11', '10', '31', '99', '5', '6', '26', '23', '7', '63', '8', '20', '18', '3', '33']
# core           INFO 	Loading data for British Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/4/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '16', '3', '4', '31', '10', '23', '18', '5', '77', '63', '55', '99', '6', '8', '7', '26', '20', '27']
# core           INFO 	Loading data for Hungarian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/3/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '18', '23', '5', '11', '3', '55', '20', '16', '26', '4', '31', '7', '8', '99', '63', '6', '10']
# core           INFO 	Loading data for Belgian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/7/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '3', '31', '23', '4', '10', '18', '11', '26', '7', '5', '16', '8', '6', '20', '99', '63', '55']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/17/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '77', '44', '23', '4', '55', '3', '10', '31', '18', '26', '7', '16', '5', '63', '99', '6', '20', '51', '11']
# core           INFO 	Loading data for Italian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2020/8/results.json failed; using cached response
# Traceback (most recent call last):
# ...
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '14', '4', '81', '16', '55', '63', '27', '77', '18', '3', '31', '23', '10', '24', '20', '44', '22', '2']
# core           INFO 	Loading data for Miami Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# logger      WARNING 	Failed to load result data from Ergast!
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '16', '55', '11', '4', '81', '63', '44', '27', '22', '18', '10', '31', '23', '14', '77', '2', '20', '24', '3']
# core           INFO 	Loading data for Monaco Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/8/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '81', '55', '4', '63', '1', '44', '22', '23', '10', '14', '3', '77', '18', '2', '24', '31', '11', '27', '20']
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/10/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '44', '63', '16', '55', '81', '11', '10', '31', '27', '14', '24', '18', '3', '77', '20', '23', '22', '2']
# core           INFO 	Loading data for Canadian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/9/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '63', '44', '81', '14', '18', '3', '10', '31', '27', '20', '77', '22', '24', '55', '23', '11', '16', '2']
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# logger      WARNING 	Failed to load result data from Ergast!
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '63', '55', '44', '16', '81', '11', '27', '31', '3', '20', '10', '22', '14', '23', '18', '77', '2', '24']
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# logger      WARNING 	Failed to load result data from Ergast!
# core        WARNING 	No result data for this session available on Ergast! (This is expected for recent sessions)
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '63', '55', '44', '16', '81', '11', '27', '31', '3', '20', '10', '22', '14', '23', '18', '77', '2', '24']
# core           INFO 	Loading data for Hungarian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/13/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['81', '4', '44', '16', '1', '55', '11', '63', '22', '18', '14', '3', '27', '23', '20', '77', '2', '31', '24', '10']
# core           INFO 	Loading data for Belgian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/14/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '81', '16', '1', '4', '55', '11', '14', '31', '3', '18', '23', '10', '20', '77', '22', '2', '27', '24', '63']
# core           INFO 	Loading data for Dutch Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/15/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['4', '1', '16', '81', '55', '11', '63', '44', '10', '14', '27', '3', '18', '23', '31', '2', '22', '20', '77', '24']
# core           INFO 	Loading data for Italian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/16/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# logger      WARNING 	Failed to add first lap time from Ergast!
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '81', '4', '55', '44', '1', '63', '11', '23', '20', '14', '43', '3', '31', '10', '77', '27', '24', '18', '22']
#   Driver             Team  Year       GP StartingTire NumberOfPitStops  \
# 0    GAS  Red Bull Racing  2019  Bahrain         SOFT                2
# 1    PER     Racing Point  2019  Bahrain         SOFT                2
# 2    LEC          Ferrari  2019  Bahrain         SOFT                2
# 3    STR     Racing Point  2019  Bahrain         SOFT                2
# 4    MAG     Haas F1 Team  2019  Bahrain         SOFT                2
#
#             TiresUsed
# 0        SOFT, MEDIUM
# 1        SOFT, MEDIUM
# 2        SOFT, MEDIUM
# 3        SOFT, MEDIUM
# 4  SOFT, MEDIUM, SOFT

# %%
norris_data = pit_stop_data[(pit_stop_data['Driver'] == 'NOR') & 
                            (pit_stop_data['GP'] == 'Monza') & 
                            (pit_stop_data['Year'] == 2024)]

# Print the filtered data
print(norris_data)
# Out:
#      Driver     Team  Year     GP StartingTire NumberOfPitStops     TiresUsed
# 2336    NOR  McLaren  2024  Monza       MEDIUM                2  MEDIUM, HARD

# %%
import fastf1 as ff1
import pandas as pd

# Enable cache
ff1.Cache.enable_cache("/Users/ainefernandez/documents/itam/8SEMESTRE/F1 Python")

# Dictionary of GPs by year
gps_by_year = {
    2019: ["Bahrain", "China", "Australia", "Japan", "Monaco", "Spain", "Canada", 
           "Austria", "Great Britain", "Hungary", "Belgium", "Azerbaijan", 
           "Singapore", "Austin", "Mexico", "Brazil", "Abu Dhabi", "Monza",
           "France", "Germany", "Russia"],

    2020: ["Bahrain", "Spain", "Austria", "Great Britain", "Hungary", "Belgium", 
           "Abu Dhabi", "Monza", "Turkey", "Portugal", "Russia", "Imola", 
           "Eifel", "Mugello", "Sakhir", "70th", "Sakhir"],

    2021: ["Bahrain", "Monaco", "Spain", "Imola", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Azerbaijan", "Austin", 
           "Mexico", "Brazil", "Abu Dhabi", "Monza", "Qatar", "Saudi Arabia",
           "France", "Netherlands", "Turkey", "Russia", "Portugal", "Styria"],

    2022: ["Bahrain", "Australia", "Japan", "Monaco", "Spain", 
           "Canada", "Austria", "Great Britain", "Hungary", 
           "Belgium", "Azerbaijan", "Singapore", "Austin", "Mexico", 
           "Brazil", "Abu Dhabi", "Monza", "Miami", "Saudi Arabia",
           "France", "Netherlands"],

    2023: ["Bahrain", "Saudi Arabia", "Australia", "Japan", 
           "Miami", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", 
           "Azerbaijan", "Singapore", "Austin", "Mexico", "Brazil", 
           "Qatar", "Abu Dhabi", "Monza", "Las Vegas"],

    2024: ["Bahrain", "Saudi Arabia", "Australia", "Japan", 
           "China", "Miami", "Monaco", "Spain", "Canada", "Austria", 
           "Great Britain", "Hungary", "Belgium", "Netherlands", "Monza"]
}

# Initialize an empty list to store strategy data
all_strategy_data = []

# Loop through each year and each GP
for year, gps in gps_by_year.items():
    for gp in gps:
        try:
            # Load the race session for each GP and year
            session = 'R'  # We're focusing on race sessions
            race = ff1.get_session(year, gp, session)
            race.load()

            # Get the laps data for the race
            laps = race.laps
            drivers = race.drivers
            drivers = [race.get_driver(driver)["Abbreviation"] for driver in drivers]

            # Extracting strategy information for each driver
            for driver in drivers:
                # Get driver details
                driver_info = race.get_driver(driver)
                team = driver_info["TeamName"]
                
                # Filter laps for the current driver
                driver_laps = laps[laps["Driver"] == driver]

                # Create a strategy string capturing compounds for each outlap
                strategy = []

                # Initialize the strategy with the starting compound
                starting_compound = driver_laps['Compound'].iloc[0]
                strategy.append(starting_compound)

                # Flag to skip the first outlap
                first_outlap_skipped = False

                # Loop through laps to find outlaps
                for i in range(len(driver_laps)):
                    # Check if the current lap is an outlap based on PitOutTime
                    if driver_laps['PitOutTime'].dt.total_seconds().iloc[i] > 0:
                        # Skip the first outlap
                        if not first_outlap_skipped:
                            first_outlap_skipped = True
                            continue
                        
                        # Capture the compound used on this outlap
                        outlap_compound = driver_laps['Compound'].iloc[i]
                        strategy.append(outlap_compound)

                # Join the strategy components with a '-'
                strategy_string = '-'.join(strategy)

                # Append the strategy data for this driver, GP, year, and team
                all_strategy_data.append({
                    'Driver': driver,
                    'Team': team,
                    'GP': gp, 
                    'Year': year,  
                    'Strategy': strategy_string
                })

        except Exception as e:
            print(f"Error loading {gp} {year}: {e}")

# Convert the list of strategy data into a DataFrame
strategy_df = pd.DataFrame(all_strategy_data)
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '16', '33', '5', '4', '7', '10', '23', '11', '99', '26', '20', '18', '63', '88', '27', '3', '55', '8']
# core           INFO 	Loading data for Chinese Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '5', '33', '16', '10', '3', '11', '7', '23', '8', '18', '20', '55', '99', '63', '88', '4', '26', '27']
# core           INFO 	Loading data for Australian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '5', '16', '20', '27', '7', '18', '26', '10', '4', '11', '23', '99', '63', '88', '8', '3', '55']
# core           INFO 	Loading data for Japanese Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '5', '44', '23', '55', '16', '10', '11', '18', '26', '4', '7', '8', '99', '20', '63', '88', '33', '3', '27']
# core           INFO 	Loading data for Monaco Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '5', '77', '33', '10', '55', '26', '23', '3', '8', '4', '11', '27', '20', '63', '18', '7', '88', '99', '16']
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '5', '16', '10', '20', '55', '26', '8', '23', '3', '27', '7', '11', '99', '63', '88', '18', '4']
# core           INFO 	Loading data for Canadian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '5', '16', '77', '33', '3', '27', '10', '18', '26', '55', '11', '99', '8', '7', '63', '20', '88', '23', '4']
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '16', '77', '5', '44', '4', '10', '55', '7', '99', '11', '3', '27', '18', '23', '8', '26', '63', '20', '88']
# core           INFO 	Loading data for British Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '16', '10', '33', '55', '3', '7', '26', '27', '4', '23', '18', '63', '88', '5', '11', '99', '8', '20']
# core           INFO 	Loading data for Hungarian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '5', '16', '55', '10', '7', '77', '4', '23', '11', '27', '20', '3', '26', '63', '18', '99', '88', '8']
# core           INFO 	Loading data for Belgian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '44', '77', '5', '23', '11', '26', '27', '10', '18', '4', '20', '8', '3', '63', '7', '88', '99', '55', '33']
# core           INFO 	Loading data for Azerbaijan Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '5', '33', '16', '11', '55', '4', '18', '7', '23', '99', '20', '27', '63', '88', '10', '8', '26', '3']
# core           INFO 	Loading data for Singapore Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['5', '16', '33', '44', '77', '23', '4', '10', '27', '99', '8', '55', '18', '3', '26', '88', '20', '7', '11', '63']
# core           INFO 	Loading data for United States Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '44', '33', '16', '23', '3', '4', '55', '27', '11', '7', '26', '18', '99', '8', '10', '63', '20', '88', '5']
# core           INFO 	Loading data for Mexican Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '5', '77', '16', '23', '33', '11', '3', '10', '27', '26', '18', '55', '99', '20', '63', '8', '88', '7', '4']
# core           INFO 	Loading data for Brazilian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '10', '55', '7', '99', '3', '44', '4', '11', '26', '20', '63', '8', '23', '27', '88', '5', '16', '18', '77']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '16', '77', '5', '23', '11', '4', '26', '55', '3', '27', '7', '20', '8', '99', '63', '10', '88', '18']
# core           INFO 	Loading data for Italian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '77', '44', '3', '27', '23', '11', '33', '99', '4', '10', '18', '5', '63', '7', '8', '88', '20', '26', '55']
# core           INFO 	Loading data for French Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '16', '33', '5', '55', '7', '27', '4', '10', '3', '11', '18', '26', '23', '99', '20', '88', '63', '8']
# core           INFO 	Loading data for German Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '5', '26', '18', '55', '23', '8', '20', '44', '88', '63', '7', '99', '10', '77', '27', '16', '4', '3', '11']
# core           INFO 	Loading data for Russian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '16', '33', '23', '55', '11', '4', '20', '27', '18', '26', '7', '10', '99', '88', '63', '5', '3', '8']
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '23', '4', '55', '10', '3', '77', '31', '16', '26', '63', '5', '6', '7', '99', '20', '11', '18', '8']
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '18', '11', '55', '5', '23', '10', '4', '3', '26', '31', '7', '20', '99', '63', '6', '8', '16']
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	Driver  8: Lap timing integrity check failed for 1 lap(s)
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '16', '4', '44', '55', '11', '10', '31', '99', '5', '6', '26', '23', '7', '63', '8', '20', '18', '3', '33']
# core           INFO 	Loading data for British Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '16', '3', '4', '31', '10', '23', '18', '5', '77', '63', '55', '99', '6', '8', '7', '26', '20', '27']
# core           INFO 	Loading data for Hungarian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '18', '23', '5', '11', '3', '55', '20', '16', '26', '4', '31', '7', '8', '99', '63', '6', '10']
# core           INFO 	Loading data for Belgian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '3', '31', '23', '4', '10', '18', '11', '26', '7', '5', '16', '8', '6', '20', '99', '63', '55']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '77', '44', '23', '4', '55', '3', '10', '31', '18', '26', '7', '16', '5', '63', '99', '6', '20', '51', '11']
# core           INFO 	Loading data for Italian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['10', '55', '18', '4', '77', '3', '44', '31', '26', '11', '6', '8', '7', '63', '23', '99', '33', '16', '20', '5']
# core           INFO 	Loading data for Turkish Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '11', '5', '16', '55', '33', '23', '4', '18', '3', '31', '26', '10', '77', '7', '63', '20', '8', '6', '99']
# core           INFO 	Loading data for Portuguese Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '16', '10', '55', '11', '31', '3', '5', '7', '23', '4', '63', '99', '20', '8', '6', '26', '18']
# core           INFO 	Loading data for Russian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['77', '33', '44', '11', '3', '16', '31', '26', '10', '23', '99', '20', '5', '7', '4', '6', '8', '63', '55', '18']
# core           INFO 	Loading data for Emilia Romagna Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '3', '26', '16', '11', '55', '4', '7', '99', '6', '5', '18', '8', '23', '63', '33', '20', '31', '10']
# core           INFO 	Loading data for Eifel Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '3', '11', '55', '10', '16', '27', '8', '99', '5', '7', '20', '6', '26', '4', '23', '31', '77', '63']
# core           INFO 	Loading data for Tuscan Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '23', '3', '11', '4', '26', '16', '7', '5', '63', '8', '18', '31', '6', '20', '99', '55', '33', '10']
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '23', '4', '55', '10', '3', '77', '31', '16', '26', '63', '5', '6', '7', '99', '20', '11', '18', '8']
# core           INFO 	Loading data for 70th Anniversary Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '77', '16', '23', '18', '27', '31', '4', '26', '10', '5', '55', '3', '7', '8', '99', '63', '6', '20']
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '23', '4', '55', '10', '3', '77', '31', '16', '26', '63', '5', '6', '7', '99', '20', '11', '18', '8']
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '4', '11', '16', '3', '55', '22', '18', '7', '99', '31', '63', '5', '47', '10', '6', '14', '9']
# core           INFO 	Loading data for Monaco Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '55', '4', '11', '5', '10', '44', '18', '31', '99', '7', '3', '14', '63', '6', '22', '9', '47', '77', '16']
# core           INFO 	Loading data for Spanish Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '16', '11', '3', '55', '4', '31', '10', '18', '7', '5', '63', '99', '6', '14', '47', '9', '22']
# core           INFO 	Loading data for Emilia Romagna Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '4', '16', '55', '3', '10', '18', '31', '14', '11', '22', '7', '99', '5', '47', '9', '77', '63', '6']
# core           INFO 	Loading data for Styrian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '77', '11', '4', '55', '16', '18', '14', '22', '7', '5', '3', '31', '99', '47', '6', '9', '63', '10']
# core           INFO 	Loading data for British Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '16', '77', '4', '3', '55', '14', '18', '31', '22', '10', '63', '99', '6', '7', '11', '9', '47', '5', '33']
# core           INFO 	Loading data for Hungarian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['31', '44', '55', '14', '10', '22', '6', '63', '33', '7', '3', '47', '99', '9', '4', '77', '11', '16', '18', '5']
# core           INFO 	Loading data for Belgian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '63', '44', '3', '5', '10', '31', '16', '6', '55', '14', '77', '99', '4', '22', '47', '9', '7', '11', '18']
# core           INFO 	Loading data for Azerbaijan Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['11', '5', '10', '16', '4', '14', '22', '55', '3', '7', '99', '77', '47', '9', '44', '6', '63', '33', '18', '31']
# core           INFO 	Loading data for United States Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '11', '16', '3', '77', '55', '4', '22', '5', '99', '18', '7', '63', '6', '47', '9', '14', '31', '10']
# core           INFO 	Loading data for Mexico City Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '11', '10', '16', '55', '5', '7', '14', '4', '99', '3', '31', '18', '77', '63', '6', '9', '47', '22']
# core           INFO 	Loading data for São Paulo Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '11', '16', '55', '10', '31', '14', '4', '5', '7', '63', '99', '22', '6', '9', '47', '3', '18']
# core           INFO 	Loading data for Abu Dhabi Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# core        WARNING 	No lap data for driver 9
# core        WARNING 	Failed to perform lap accuracy check - all laps marked as inaccurate.
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '55', '22', '10', '77', '4', '14', '31', '16', '5', '3', '18', '47', '11', '6', '99', '63', '7', '9']
# core           INFO 	Loading data for Italian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Error loading Abu Dhabi 2021: single positional indexer is out-of-bounds
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['3', '4', '77', '16', '11', '55', '18', '14', '63', '31', '6', '5', '99', '88', '47', '9', '44', '33', '10', '22']
# core           INFO 	Loading data for Qatar Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '14', '11', '31', '18', '55', '16', '4', '5', '10', '3', '22', '7', '99', '47', '63', '9', '6', '77']
# core           INFO 	Loading data for Saudi Arabian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '33', '77', '31', '3', '10', '16', '55', '99', '4', '18', '6', '14', '22', '7', '5', '11', '9', '63', '47']
# core           INFO 	Loading data for French Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# ...
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# Request for URL https://ergast.com/api/f1/2024/9/laps/1.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '63', '44', '81', '14', '18', '3', '10', '31', '27', '20', '77', '22', '24', '55', '23', '11', '16', '2']
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/11/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# Request for URL https://ergast.com/api/f1/2024/11/laps/1.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['63', '81', '55', '44', '1', '27', '11', '20', '3', '10', '16', '31', '18', '22', '23', '77', '24', '14', '2', '4']
# core           INFO 	Loading data for Austrian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/11/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# Request for URL https://ergast.com/api/f1/2024/11/laps/1.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['63', '81', '55', '44', '1', '27', '11', '20', '3', '10', '16', '31', '18', '22', '23', '77', '24', '14', '2', '4']
# core           INFO 	Loading data for Hungarian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/13/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# Request for URL https://ergast.com/api/f1/2024/13/laps/1.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['81', '4', '44', '16', '1', '55', '11', '63', '22', '18', '14', '3', '27', '23', '20', '77', '2', '31', '24', '10']
# core           INFO 	Loading data for Belgian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/14/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# Request for URL https://ergast.com/api/f1/2024/14/laps/1.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '81', '16', '1', '4', '55', '11', '14', '31', '3', '18', '23', '10', '20', '77', '22', '2', '27', '24', '63']
# core           INFO 	Loading data for Dutch Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/15/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# Request for URL https://ergast.com/api/f1/2024/15/laps/1.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['4', '1', '16', '81', '55', '11', '63', '44', '10', '14', '27', '3', '18', '23', '31', '2', '22', '20', '77', '24']
# core           INFO 	Loading data for Italian Grand Prix - Race [v3.0.7]
# req            INFO 	Using cached data for driver_info
# Request for URL https://ergast.com/api/f1/2024/16/results.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# Request for URL https://ergast.com/api/f1/2024/16/laps/1.json failed; using cached response
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 230, in _resend_and_ignore
#     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/requests_cache/session.py", line 189, in _send_and_cache
#     response = super().send(request, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 122, in send
#     lim.limit()
#   File "/opt/anaconda3/lib/python3.9/site-packages/fastf1/req.py", line 99, in limit
#     raise RateLimitExceededError(self._info)
# fastf1.req.RateLimitExceededError: ergast.com: 200 calls/h
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['16', '81', '4', '55', '44', '1', '63', '11', '23', '20', '14', '43', '3', '31', '10', '77', '27', '24', '18', '22']

# %%
team_mapping = {
    'Toro Rosso': 'RB',
    'AlphaTauri':'RB',
    'Renault': 'Alpine',
    'Alfa Romeo Racing': 'Kick Sauber',
    'Alfa Romeo': 'Kick Sauber',
    'Racing Point': 'Aston Martin'
}

# Replace team names in the 'Team' column using the mapping
strategy_df['Team'] = strategy_df['Team'].replace(team_mapping)

# Verificar los cambios
print(strategy_df['Team'].unique())
strategy_df.to_csv("Strategy.csv")
# Out:
# ['Mercedes' 'Ferrari' 'Red Bull Racing' 'McLaren' 'Kick Sauber' 'RB'
#  'Aston Martin' 'Haas F1 Team' 'Williams' 'Alpine' 'nan']

# %%
import pandas as pd

# Load all the DataFrames
#q1 = pd.read_csv('PaperQ1Data2.csv')    # Primary DataFrame
#q2 = pd.read_csv('PaperQ2Data2.csv')    # Additional DataFrame 1
race = pd.read_csv('PaperRaceData2.csv')  # Additional DataFrame 2
#FP1 = pd.read_csv('PaperFP1Data2.csv')   # Additional DataFrame 3
#FP2 = pd.read_csv('PaperFP2Data2.csv')   # Additional DataFrame 4
#FP3 = pd.read_csv('PaperFP3Data2.csv')   # Additional DataFrame 5
pitstop=pd.read_csv('PitStopData.csv')
# Start by merging q1 and q2
merged_df = pd.merge(q1, q2, on=['GP', 'Year', 'Driver','Team'], how='left')

# Merge the result with race data
merged_df = pd.merge(merged_df, race, on=['GP', 'Year', 'Driver','Team'], how='left')

# Merge with FP1
merged_df = pd.merge(merged_df, FP1, on=['GP', 'Year', 'Driver','Team'], how='left')

# Merge with FP2
merged_df = pd.merge(merged_df, FP2, on=['GP', 'Year', 'Driver','Team'], how='left')

# Merge with FP3
merged_df = pd.merge(merged_df, FP3, on=['GP', 'Year', 'Driver','Team'], how='left')

merged_df = pd.merge(merged_df, pitstop, on=['GP', 'Year', 'Driver','Team'], how='left')

# Display the merged DataFrame
print(merged_df)

# Save the merged DataFrame to a CSV file
#merged_df.to_csv("PaperFullData2.csv", index=False)
# Create a new variable to indicate if the driver made it to Q2
merged_df['MadeItToQ2'] = (merged_df['GapToKnockoutQ1'] <= 0).astype(int)

# Create a new variable to indicate if the driver made it to Q3
merged_df['MadeItToQ3'] = (merged_df['GapToKnockoutQ2'] <= 0).astype(int)

print(merged_df)
#merged_df.to_csv("PaperFullData2.csv", index=False)
# Out:
#      Driver          Team  LapTimeQ1  PositionQ1  GapToKnockoutQ1  Year  \
# 0       LEC       Ferrari     88.495           1           -1.464  2019
# 1       VET       Ferrari     88.733           2           -1.226  2019
# 2       HAM      Mercedes     89.262           3           -0.697  2019
# 3       NOR       McLaren     89.381           4           -0.578  2019
# 4       BOT      Mercedes     89.498           5           -0.461  2019
# ...     ...           ...        ...         ...              ...   ...
# 4414    TSU            RB     80.945          16            0.044  2024
# 4415    STR  Aston Martin     81.013          17            0.112  2024
# 4416    COL      Williams     81.061          18            0.160  2024
# 4417    BOT   Kick Sauber     81.101          19            0.200  2024
# 4418    ZHO   Kick Sauber     81.445          20            0.544  2024
#
#            GP  LapTimeQ2  PositionQ2  GapToKnockoutQ2  ...  PositionFP1  \
# 0     Bahrain     88.046         1.0           -1.425  ...          1.0
# 1     Bahrain     88.356         2.0           -1.115  ...          2.0
# 2     Bahrain     88.578         3.0           -0.893  ...          4.0
# 3     Bahrain     89.258         9.0           -0.213  ...         15.0
# 4     Bahrain     88.830         4.0           -0.641  ...          3.0
# ...       ...        ...         ...              ...  ...          ...
# 4414    Monza        NaN         NaN              NaN  ...         13.0
# 4415    Monza        NaN         NaN              NaN  ...         16.0
# 4416    Monza        NaN         NaN              NaN  ...         17.0
# 4417    Monza        NaN         NaN              NaN  ...          5.0
# 4418    Monza        NaN         NaN              NaN  ...         15.0
#
#       LapTimeFP2 GapToFastestFP2  PositionFP2  LapTimeFP3  GapToFastestFP3  \
# 0         88.881           0.035          2.0      89.569            0.000
# 1         88.846           0.000          1.0      89.738            0.169
# 2         89.449           0.603          3.0      90.334            0.765
# 3         90.017           1.171          8.0      90.955            1.386
# 4         89.557           0.711          4.0      90.389            0.820
# ...          ...             ...          ...         ...              ...
# 4414      81.735           0.997         16.0      81.141            1.024
# 4415      81.363           0.625         10.0      81.157            1.040
# 4416      81.784           1.046         17.0      80.905            0.788
# 4417      81.461           0.723         11.0      81.357            1.240
# 4418      82.223           1.485         20.0      82.035            1.918
#
#       PositionFP3  StartingTire  NumberOfPitStops           TiresUsed
# 0             1.0          SOFT               2.0        SOFT, MEDIUM
# 1             2.0          SOFT               3.0  SOFT, MEDIUM, SOFT
# 2             3.0          SOFT               2.0        SOFT, MEDIUM
# 3             7.0          SOFT               2.0  SOFT, MEDIUM, SOFT
# 4             4.0          SOFT               2.0  SOFT, MEDIUM, SOFT
# ...           ...           ...               ...                 ...
# 4414         13.0          HARD               0.0                HARD
# 4415         15.0          HARD               3.0  HARD, MEDIUM, SOFT
# 4416          9.0        MEDIUM               1.0        MEDIUM, HARD
# 4417         19.0          HARD               1.0        HARD, MEDIUM
# 4418         20.0        MEDIUM               1.0        MEDIUM, HARD
#
# [4419 rows x 31 columns]
#      Driver          Team  LapTimeQ1  PositionQ1  GapToKnockoutQ1  Year  \
# 0       LEC       Ferrari     88.495           1           -1.464  2019
# 1       VET       Ferrari     88.733           2           -1.226  2019
# 2       HAM      Mercedes     89.262           3           -0.697  2019
# 3       NOR       McLaren     89.381           4           -0.578  2019
# 4       BOT      Mercedes     89.498           5           -0.461  2019
# ...     ...           ...        ...         ...              ...   ...
# 4414    TSU            RB     80.945          16            0.044  2024
# 4415    STR  Aston Martin     81.013          17            0.112  2024
# 4416    COL      Williams     81.061          18            0.160  2024
# 4417    BOT   Kick Sauber     81.101          19            0.200  2024
# 4418    ZHO   Kick Sauber     81.445          20            0.544  2024
#
#            GP  LapTimeQ2  PositionQ2  GapToKnockoutQ2  ...  GapToFastestFP2  \
# 0     Bahrain     88.046         1.0           -1.425  ...            0.035
# 1     Bahrain     88.356         2.0           -1.115  ...            0.000
# 2     Bahrain     88.578         3.0           -0.893  ...            0.603
# 3     Bahrain     89.258         9.0           -0.213  ...            1.171
# 4     Bahrain     88.830         4.0           -0.641  ...            0.711
# ...       ...        ...         ...              ...  ...              ...
# 4414    Monza        NaN         NaN              NaN  ...            0.997
# 4415    Monza        NaN         NaN              NaN  ...            0.625
# 4416    Monza        NaN         NaN              NaN  ...            1.046
# 4417    Monza        NaN         NaN              NaN  ...            0.723
# 4418    Monza        NaN         NaN              NaN  ...            1.485
#
#       PositionFP2 LapTimeFP3  GapToFastestFP3  PositionFP3  StartingTire  \
# 0             2.0     89.569            0.000          1.0          SOFT
# 1             1.0     89.738            0.169          2.0          SOFT
# 2             3.0     90.334            0.765          3.0          SOFT
# 3             8.0     90.955            1.386          7.0          SOFT
# 4             4.0     90.389            0.820          4.0          SOFT
# ...           ...        ...              ...          ...           ...
# 4414         16.0     81.141            1.024         13.0          HARD
# 4415         10.0     81.157            1.040         15.0          HARD
# 4416         17.0     80.905            0.788          9.0        MEDIUM
# 4417         11.0     81.357            1.240         19.0          HARD
# 4418         20.0     82.035            1.918         20.0        MEDIUM
#
#       NumberOfPitStops           TiresUsed  MadeItToQ2  MadeItToQ3
# 0                  2.0        SOFT, MEDIUM           1           1
# 1                  3.0  SOFT, MEDIUM, SOFT           1           1
# 2                  2.0        SOFT, MEDIUM           1           1
# 3                  2.0  SOFT, MEDIUM, SOFT           1           1
# 4                  2.0  SOFT, MEDIUM, SOFT           1           1
# ...                ...                 ...         ...         ...
# 4414               0.0                HARD           0           0
# 4415               3.0  HARD, MEDIUM, SOFT           0           0
# 4416               1.0        MEDIUM, HARD           0           0
# 4417               1.0        HARD, MEDIUM           0           0
# 4418               1.0        MEDIUM, HARD           0           0
#
# [4419 rows x 33 columns]

# %%
data = pd.read_csv("PaperFullData5.csv")
print(data)
num_duplicates = data.duplicated().sum()
print(f"Número de registros duplicados: {num_duplicates}")

len(strategy_df)
# Out:
#       Driver          Team  LapTimeQ1  PositionQ1  GapToKnockoutQ1  Year  \
# 0        LEC       Ferrari     88.495           1           -1.464  2019
# 1        VET       Ferrari     88.733           2           -1.226  2019
# 2        HAM      Mercedes     89.262           3           -0.697  2019
# 3        NOR       McLaren     89.381           4           -0.578  2019
# 4        BOT      Mercedes     89.498           5           -0.461  2019
# ...      ...           ...        ...         ...              ...   ...
# 10654    TSU            RB     80.945          16            0.044  2024
# 10655    STR  Aston Martin     81.013          17            0.112  2024
# 10656    COL      Williams     81.061          18            0.160  2024
# 10657    BOT   Kick Sauber     81.101          19            0.200  2024
# 10658    ZHO   Kick Sauber     81.445          20            0.544  2024
#
#             GP  LapTimeQ2  PositionQ2  GapToKnockoutQ2  ...  LapTimeFP3  \
# 0      Bahrain     88.046         1.0           -1.425  ...      89.569
# 1      Bahrain     88.356         2.0           -1.115  ...      89.738
# 2      Bahrain     88.578         3.0           -0.893  ...      90.334
# 3      Bahrain     89.258         9.0           -0.213  ...      90.955
# 4      Bahrain     88.830         4.0           -0.641  ...      90.389
# ...        ...        ...         ...              ...  ...         ...
# 10654    Monza        NaN         NaN              NaN  ...      81.141
# 10655    Monza        NaN         NaN              NaN  ...      81.157
# 10656    Monza        NaN         NaN              NaN  ...      80.905
# 10657    Monza        NaN         NaN              NaN  ...      81.357
# 10658    Monza        NaN         NaN              NaN  ...      82.035
#
#        GapToFastestFP3 PositionFP3  StartingTire  NumberOfPitStops  \
# 0                0.000         1.0          SOFT                 1
# 1                0.169         2.0          SOFT                 1
# 2                0.765         3.0          SOFT                 1
# 3                1.386         7.0          SOFT                 1
# 4                0.820         4.0          SOFT                 1
# ...                ...         ...           ...               ...
# 10654            1.024        13.0          HARD                 0
# 10655            1.040        15.0          HARD                 2
# 10656            0.788         9.0        MEDIUM                 1
# 10657            1.240        19.0          HARD                 1
# 10658            1.918        20.0        MEDIUM                 1
#
#                 TiresUsed  MadeItToQ2  MadeItToQ3          Strategy  DNF
# 0            SOFT, MEDIUM           1           1       SOFT-MEDIUM    0
# 1      SOFT, MEDIUM, SOFT           1           1       SOFT-MEDIUM    0
# 2            SOFT, MEDIUM           1           1       SOFT-MEDIUM    0
# 3      SOFT, MEDIUM, SOFT           1           1       SOFT-MEDIUM    0
# 4      SOFT, MEDIUM, SOFT           1           1       SOFT-MEDIUM    0
# ...                   ...         ...         ...               ...  ...
# 10654                HARD           0           0              HARD    0
# 10655  HARD, MEDIUM, SOFT           0           0  HARD-MEDIUM-SOFT    0
# 10656        MEDIUM, HARD           0           0       MEDIUM-HARD    0
# 10657        HARD, MEDIUM           0           0       HARD-MEDIUM    0
# 10658        MEDIUM, HARD           0           0       MEDIUM-HARD    0
#
# [10659 rows x 35 columns]
# Número de registros duplicados: 8286
# 2354

# %%
data = pd.read_csv("PaperFullData7.csv")

merged_df = pd.merge(data,strategy_df, on=['GP', 'Year', 'Driver','Team'], how='left')
merged_df.to_csv("PaperFullData8a.csv", index=False)
print(merged_df)
# Out:
#      Driver          Team  LapTimeQ1  PositionQ1  GapToKnockoutQ1  Year  \
# 0       LEC       Ferrari     88.495           1           -1.464  2019
# 1       VET       Ferrari     88.733           2           -1.226  2019
# 2       HAM      Mercedes     89.262           3           -0.697  2019
# 3       NOR       McLaren     89.381           4           -0.578  2019
# 4       BOT      Mercedes     89.498           5           -0.461  2019
# ...     ...           ...        ...         ...              ...   ...
# 2314    TSU            RB     80.945          16            0.044  2024
# 2315    STR  Aston Martin     81.013          17            0.112  2024
# 2316    COL      Williams     81.061          18            0.160  2024
# 2317    BOT   Kick Sauber     81.101          19            0.200  2024
# 2318    ZHO   Kick Sauber     81.445          20            0.544  2024
#
#            GP  LapTimeQ2  PositionQ2  GapToKnockoutQ2  ...  GapToFastestFP3  \
# 0     Bahrain     88.046         1.0           -1.425  ...            0.000
# 1     Bahrain     88.356         2.0           -1.115  ...            0.169
# 2     Bahrain     88.578         3.0           -0.893  ...            0.765
# 3     Bahrain     89.258         9.0           -0.213  ...            1.386
# 4     Bahrain     88.830         4.0           -0.641  ...            0.820
# ...       ...        ...         ...              ...  ...              ...
# 2314    Monza        NaN         NaN              NaN  ...            1.024
# 2315    Monza        NaN         NaN              NaN  ...            1.040
# 2316    Monza        NaN         NaN              NaN  ...            0.788
# 2317    Monza        NaN         NaN              NaN  ...            1.240
# 2318    Monza        NaN         NaN              NaN  ...            1.918
#
#       PositionFP3 StartingTire  NumberOfPitStops           TiresUsed  \
# 0             1.0         SOFT                 1        SOFT, MEDIUM
# 1             2.0         SOFT                 1  SOFT, MEDIUM, SOFT
# 2             3.0         SOFT                 1        SOFT, MEDIUM
# 3             7.0         SOFT                 1  SOFT, MEDIUM, SOFT
# 4             4.0         SOFT                 1  SOFT, MEDIUM, SOFT
# ...           ...          ...               ...                 ...
# 2314         13.0         HARD                 0                HARD
# 2315         15.0         HARD                 2  HARD, MEDIUM, SOFT
# 2316          9.0       MEDIUM                 1        MEDIUM, HARD
# 2317         19.0         HARD                 1        HARD, MEDIUM
# 2318         20.0       MEDIUM                 1        MEDIUM, HARD
#
#       MadeItToQ2  MadeItToQ3        Strategy_x  DNF               Strategy_y
# 0              1           1       SOFT-MEDIUM    0       SOFT-MEDIUM-MEDIUM
# 1              1           1       SOFT-MEDIUM    0  SOFT-MEDIUM-MEDIUM-SOFT
# 2              1           1       SOFT-MEDIUM    0         SOFT-SOFT-MEDIUM
# 3              1           1       SOFT-MEDIUM    0         SOFT-MEDIUM-SOFT
# 4              1           1       SOFT-MEDIUM    0       SOFT-MEDIUM-MEDIUM
# ...          ...         ...               ...  ...                      ...
# 2314           0           0              HARD    0                     HARD
# 2315           0           0  HARD-MEDIUM-SOFT    0    HARD-HARD-MEDIUM-SOFT
# 2316           0           0       MEDIUM-HARD    0              MEDIUM-HARD
# 2317           0           0       HARD-MEDIUM    0              HARD-MEDIUM
# 2318           0           0       MEDIUM-HARD    0              MEDIUM-HARD
#
# [2319 rows x 36 columns]

# %%
pitlane=pd.read_csv("Pitlane.csv")
print(pitlane)
# Out:
#       Driver  Year       GP  Pitlane
# 0        LEC  2019  Bahrain      0.0
# 1        VET  2019  Bahrain      0.0
# 2        HAM  2019  Bahrain      0.0
# 3        NOR  2019  Bahrain      0.0
# 4        BOT  2019  Bahrain      0.0
# ...      ...   ...      ...      ...
# 10654    TSU  2024    Monza      NaN
# 10655    STR  2024    Monza      NaN
# 10656    COL  2024    Monza      NaN
# 10657    BOT  2024    Monza      NaN
# 10658    ZHO  2024    Monza      NaN
#
# [10659 rows x 4 columns]

# %%
q1 = q1.rename(columns={"GapToKnockout": "GapToKnockoutQ1"})
q1 = q1.rename(columns={"LapTime": "LapTimeQ1"})
q1 = q1.rename(columns={"Position": "PositionQ1"})
#q1 = q1.drop('Session', axis=1)

FP3 = FP3.drop('Session', axis=1)

# %%
q2= q2.rename(columns={"GapToKnockout": "GapToKnockoutQ2"})
q2=q2.rename(columns={"LapTime": "LapTimeQ2"})
q2 = q2.rename(columns={"Position": "PositionQ2"})

# %%
FP1=FP1.rename(columns={"LapTime": "LapTimeFP1"})
FP1=FP1.rename(columns={"Position": "PositionFP1"})
FP2=FP2.rename(columns={"LapTime": "LapTimeFP2"})
FP2=FP2.rename(columns={"Position": "PositionFP2"})
FP3=FP3.rename(columns={"LapTime": "LapTimeFP3"})
FP3=FP3.rename(columns={"Position": "PositionFP3"})
